# %% [markdown]
# <a href="https://colab.research.google.com/github/sayaliKutwal/Computer-Vision-Nanodegree-Exercises/blob/master/1.%20Introduction%20to%20Computer%20Vision/2_Visualizing_RGB_Channels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RGB colorspace

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %% [markdown]
# # Mount drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
os.chdir('/gdrive/My Drive/000 Udacity Nanodegree/CVND/1. Introduction to Computer Vision')

# %% [markdown]
# Link for image https://github.com/sayaliKutwal/CVND_Exercises/blob/master/1_1_Image_Representation/images/wa_state_highway.jpg

# %% [markdown]
# # Read image

# %%
# Read in the image
image = mpimg.imread('wa_state_highway.jpg')

plt.imshow(image)

# %% [markdown]
# # RGB Channels

# %% [markdown]
# Visualize the levels of each  color channel.

# %%
# Isolate RGB channels
r = image[:,:,0]
g = image[:,:,1]
b = image[:,:,2]

#Visualize the individual clor channels
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,10))

ax1.set_title('R channel')
ax1.imshow(r, cmap='gray')
ax2.set_title('G Channel')
ax2.imshow(g, cmap='gray')
ax3.set_title('B Channel')
ax3.imshow(b, cmap='gray')


## Which area has the lowest value for red? What about for blue?
